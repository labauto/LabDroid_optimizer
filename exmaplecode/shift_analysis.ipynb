# %%
# %matplotlib inline
import os
import numpy as np
import pandas as pd
import GPyOpt 
import pickle

import matplotlib.pyplot as plt

from acqsum_utils import calc_results

# %%
filenames = ["r5.pkl","r7.pkl","r8.pkl"]
raitos = []
for name in filenames:
    loadpath = "../data/nextquery/model/" + name
    with open(loadpath, mode='rb') as f:
        model = pickle.load(f)
    raito_minus, raito_plus = calc_results(model)
    print (name)
    print (raito_minus)
    print (raito_plus)
# Out:
# r5.pkl
# 1.2347569879817604
# 0.6613030366267395
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-028af28629a5> in <module>()
#       5     with open(loadpath, mode='rb') as f:
#       6         model = pickle.load(f)
# ----> 7     raito_minus, raito_plus = calc_results(model)
#       8     print (name)
#       9     print (raito_minus)
#
# ~/pyproject/rpeproject/generate_nextquery/src/acqsum_utils.py in calc_results(model, normalize)
#      50     gridX = generate_evalgrid(value_list)
#      51     size = int(gridX.shape[0]/len(value_list[2]))
# ---> 52     value, value_minus, value_plus = calc_values(model, gridX, size = size)
#      53     raito_plus = calc_raito(value, value_plus)
#      54     raito_minus = calc_raito(value, value_minus)
#
# ~/pyproject/rpeproject/generate_nextquery/src/acqsum_utils.py in calc_values(model, gridX, size, start, shift)
# ...
